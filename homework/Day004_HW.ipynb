# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11005542419","type":"PushEvent","actor":{"id":5856259,"login":"007gzs","display_login":"007gzs","gravatar_id":"","url":"https://api.github.com/users/007gzs","avatar_url":"https://avatars.githubusercontent.com/u/5856259?"},"repo":{"id":225750727,"name":"007gzs/avatars","url":"https://api.github.com/repos/007gzs/avatars"},"payload":{"push_id":4351996267,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e","before":"6ccf6ffbd02de86ce46432d72d06951f6d394b70","commits":[{"sha":"1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e","author":{"email":"007gzs@gmail.com","name":"007"},"message":"image","distinct":true,"url":"https://api.github.com/repos/007gzs/avatars/commits/1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e"}]},"public":true,"created_at":"2019-12-04T02:12:55Z"},{"id":"11005542423","type":"PushEvent","actor":{"id":54688667,"login":"mete439","display_login":"mete439","gravatar_id":"","url":"https://api.github.com/users/mete439","avatar_url":"https://avatars.githubusercontent.com/u/54688667?"},"repo":{"id":224305415,"name":"mete439/bus-mall","url":"https://api.github.com/repos/mete439/bus-mall"},"payload":{"push_id":4351996277,"size":2,"distinct_size":1,"ref":"refs/heads/master","head":"de9e22101635fc01f8fe0436de905b194483e44e","before":"768809d670b62140a06810c43d3c90f468861353","commits":[{"sha":"4746345c2b73b76daf83d3e2611acd7fa4b73c78","author":{"email":"mete439@gmail.com","name":"Tenaw Derseh"},"message":" about finishing lab11","distinct":false,"url":"https://api.github.com/repos/mete439/bus-mall/commits/4746345c2b73b76daf83d3e2611acd7fa4b73c78"},{"sha":"de9e22101635fc01f8fe0436de905b194483e44e","author":{"email":"54688667+mete439@users.noreply.github.com","name":"mete439"},"message":"Merge pull request #3 from mete439/lab11_part1\\n\\n about finishing lab11","distinct":true,"url":"https://api.github.com/repos/mete439/bus-mall/commits/de9e22101635fc01f8fe0436de905b194483e44e"}]},"public":true,"created_at":"2019-12-04T02:12:55Z"},{"id":"11005542427","type":"CreateEvent","actor":{"id":47343023,"login":"Stevenwthornton0","display_login":"Stevenwthornton0","gravatar_id":"","url":"https://api.github.com/users/Stevenwthornton0","avatar_url":"https://avatars.githubusercontent.com/u/47343023?"},"repo":{"id":225758757,"name":"Stevenwthornton0/Brewbook_server","url":"https://api.github.com/repos/Stevenwthornton0/Brewbook_server"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-04T02:12:55Z"},{"id":"11005542418","type":"PushEvent","actor":{"id":4135267,"login":"omiend","display_login":"omiend","gravatar_id":"","url":"https://api.github.com/users/omiend","avatar_url":"https://avatars.githubusercontent.com/u/4135267?"},"repo":{"id":101039310,"name":"omiend/my_strongest_ror","url":"https://api.github.com/repos/omiend/my_strongest_ror"},"payload":{"push_id":4351996272,"size":2,"distinct_size":1,"ref":"refs/heads/master","head":"a5d9ff8c4a3103f8a98f21549c7a69b31ee05448","before":"457c077ea1bd263e505259be8ba0206ae218e756","commits":[{"sha":"470f8819884f6fabe209e623ea36f15675189424","author":{"email":"49699333+dependabot[bot]@users.noreply.github.com","name":"dependabot[bot]"},"message":"Bump rubyzip from 1.2.1 to 1.3.0\\n\\nBumps [rubyzip](https://github.com/rubyzip/rubyzip) from 1.2.1 to 1.3.0.\\n- [Release notes](https://github.com/rubyzip/rubyzip/releases)\\n- [Changelog](https://github.com/rubyzip/rubyzip/blob/master/Changelog.md)\\n- [Commits](https://github.com/rubyzip/rubyzip/compare/v1.2.1...v1.3.0)\\n\\nSigned-off-by: dependabot[bot] <support@github.com>","distinct":false,"url":"https://api.github.com/repos/omiend/my_strongest_ror/commits/470f8819884f6fabe209e623ea36f15675189424"},{"sha":"a5d9ff8c4a3103f8a98f21549c7a69b31ee05448","author":{"email":"omiend@gmail.com","name":"omiend"},"message":"Merge pull request #9 from omiend/dependabot/bundler/rubyzip-1.3.0\\n\\nBump rubyzip from 1.2.1  ...

# %%
import json
json.loads(r.text)
# Out:
# [{'id': '11005542419',
#   'type': 'PushEvent',
#   'actor': {'id': 5856259,
#    'login': '007gzs',
#    'display_login': '007gzs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/007gzs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5856259?'},
#   'repo': {'id': 225750727,
#    'name': '007gzs/avatars',
#    'url': 'https://api.github.com/repos/007gzs/avatars'},
#   'payload': {'push_id': 4351996267,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e',
#    'before': '6ccf6ffbd02de86ce46432d72d06951f6d394b70',
#    'commits': [{'sha': '1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e',
#      'author': {'email': '007gzs@gmail.com', 'name': '007'},
#      'message': 'image',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/007gzs/avatars/commits/1513bf3ecd8c09e962d9f96636be0cc0d4c5c94e'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542423',
#   'type': 'PushEvent',
#   'actor': {'id': 54688667,
#    'login': 'mete439',
#    'display_login': 'mete439',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mete439',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54688667?'},
#   'repo': {'id': 224305415,
#    'name': 'mete439/bus-mall',
#    'url': 'https://api.github.com/repos/mete439/bus-mall'},
#   'payload': {'push_id': 4351996277,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'de9e22101635fc01f8fe0436de905b194483e44e',
#    'before': '768809d670b62140a06810c43d3c90f468861353',
#    'commits': [{'sha': '4746345c2b73b76daf83d3e2611acd7fa4b73c78',
#      'author': {'email': 'mete439@gmail.com', 'name': 'Tenaw Derseh'},
#      'message': ' about finishing lab11',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/mete439/bus-mall/commits/4746345c2b73b76daf83d3e2611acd7fa4b73c78'},
#     {'sha': 'de9e22101635fc01f8fe0436de905b194483e44e',
#      'author': {'email': '54688667+mete439@users.noreply.github.com',
#       'name': 'mete439'},
#      'message': 'Merge pull request #3 from mete439/lab11_part1\n\n about finishing lab11',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mete439/bus-mall/commits/de9e22101635fc01f8fe0436de905b194483e44e'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542427',
#   'type': 'CreateEvent',
#   'actor': {'id': 47343023,
#    'login': 'Stevenwthornton0',
#    'display_login': 'Stevenwthornton0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Stevenwthornton0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47343023?'},
#   'repo': {'id': 225758757,
#    'name': 'Stevenwthornton0/Brewbook_server',
#    'url': 'https://api.github.com/repos/Stevenwthornton0/Brewbook_server'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542418',
#   'type': 'PushEvent',
#   'actor': {'id': 4135267,
#    'login': 'omiend',
#    'display_login': 'omiend',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/omiend',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4135267?'},
#   'repo': {'id': 101039310,
#    'name': 'omiend/my_strongest_ror',
#    'url': 'https://api.github.com/repos/omiend/my_strongest_ror'},
#   'payload': {'push_id': 4351996272,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a5d9ff8c4a3103f8a98f21549c7a69b31ee05448',
#    'before': '457c077ea1bd263e505259be8ba0206ae218e756',
#    'commits': [{'sha': '470f8819884f6fabe209e623ea36f15675189424',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump rubyzip from 1.2.1 to 1.3.0\n\nBumps [rubyzip](https://github.com/rubyzip/rubyzip) from 1.2.1 to 1.3.0.\n- [Release notes](https://github.com/rubyzip/rubyzip/releases)\n- [Changelog](https://github.com/rubyzip/rubyzip/blob/master/Changelog.md)\n- [Commits](https://github.com/rubyzip/rubyzip/compare/v1.2.1...v1.3.0)\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/omiend/my_strongest_ror/commits/470f8819884f6fabe209e623ea36f15675189424'},
#     {'sha': 'a5d9ff8c4a3103f8a98f21549c7a69b31ee05448',
#      'author': {'email': 'omiend@gmail.com', 'name': 'omiend'},
#      'message': 'Merge pull request #9 from omiend/dependabot/bundler/rubyzip-1.3.0\n\nBump rubyzip from 1.2.1 to 1.3.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/omiend/my_strongest_ror/commits/a5d9ff8c4a3103f8a98f21549c7a69b31ee05448'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542420',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 8655789,
#    'login': 'codecov-io',
#    'display_login': 'codecov-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8655789?'},
#   'repo': {'id': 39464018,
#    'name': 'apache/incubator-superset',
#    'url': 'https://api.github.com/repos/apache/incubator-superset'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/apache/incubator-superset/issues/8746',
#     'repository_url': 'https://api.github.com/repos/apache/incubator-superset',
#     'labels_url': 'https://api.github.com/repos/apache/incubator-superset/issues/8746/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/apache/incubator-superset/issues/8746/comments',
#     'events_url': 'https://api.github.com/repos/apache/incubator-superset/issues/8746/events',
#     'html_url': 'https://github.com/apache/incubator-superset/pull/8746',
#     'id': 532365932,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjMwMjY1',
#     'number': 8746,
#     'title': 'Correcting some issues with the Time-Series Table',
#     'user': {'login': 'suddjian',
#      'id': 1858430,
#      'node_id': 'MDQ6VXNlcjE4NTg0MzA=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1858430?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/suddjian',
#      'html_url': 'https://github.com/suddjian',
#      'followers_url': 'https://api.github.com/users/suddjian/followers',
#      'following_url': 'https://api.github.com/users/suddjian/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/suddjian/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/suddjian/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/suddjian/subscriptions',
#      'organizations_url': 'https://api.github.com/users/suddjian/orgs',
#      'repos_url': 'https://api.github.com/users/suddjian/repos',
#      'events_url': 'https://api.github.com/users/suddjian/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/suddjian/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1329183122,
#       'node_id': 'MDU6TGFiZWwxMzI5MTgzMTIy',
#       'url': 'https://api.github.com/repos/apache/incubator-superset/labels/size/XS',
#       'name': 'size/XS',
#       'color': 'E2D8FF',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2019-12-04T00:47:00Z',
#     'updated_at': '2019-12-04T02:12:55Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/apache/incubator-superset/pulls/8746',
#      'html_url': 'https://github.com/apache/incubator-superset/pull/8746',
#      'diff_url': 'https://github.com/apache/incubator-superset/pull/8746.diff',
#      'patch_url': 'https://github.com/apache/incubator-superset/pull/8746.patch'},
#     'body': '### CATEGORY\r\n\r\n- [x] Bug Fix\r\n- [ ] Enhancement (new features, refinement)\r\n- [ ] Refactor\r\n- [ ] Add tests\r\n- [ ] Build / Development Environment\r\n- [ ] Documentation\r\n\r\n### SUMMARY\r\n<!--- Describe the change below, including rationale and design decisions -->\r\n\r\n- Add a default value of 0 for `timeLag` (so it will use current data by default) rather than requiring the user to enter a value\r\n- Correct some placeholder text\r\n- Remove a default link to "The Art of Data Visualization" video\r\n\r\n### BEFORE/AFTER SCREENSHOTS OR ANIMATED GIF\r\n<!--- Skip this if not applicable -->\r\n\r\n### TEST PLAN\r\n<!--- What steps should be taken to verify the changes -->\r\n\r\n### ADDITIONAL INFORMATION\r\n<!--- Check any relevant boxes with "x" -->\r\n<!--- HINT: Include "Fixes #nnn" if you are fixing an existing issue -->\r\n- [x] Has associated issue: Fixes #8323\r\n- [ ] Changes UI\r\n- [ ] Requires DB Migration.\r\n- [ ] Confirm DB Migration upgrade and downgrade tested.\r\n- [ ] Introduces new feature or API\r\n- [ ] Removes existing feature or API\r\n\r\n### REVIEWERS\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/apache/incubator-superset/issues/comments/561443671',
#     'html_url': 'https://github.com/apache/incubator-superset/pull/8746#issuecomment-561443671',
#     'issue_url': 'https://api.github.com/repos/apache/incubator-superset/issues/8746',
#     'id': 561443671,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MTQ0MzY3MQ==',
#     'user': {'login': 'codecov-io',
#      'id': 8655789,
#      'node_id': 'MDQ6VXNlcjg2NTU3ODk=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/8655789?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov-io',
#      'html_url': 'https://github.com/codecov-io',
#      'followers_url': 'https://api.github.com/users/codecov-io/followers',
#      'following_url': 'https://api.github.com/users/codecov-io/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov-io/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov-io/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov-io/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov-io/orgs',
#      'repos_url': 'https://api.github.com/users/codecov-io/repos',
#      'events_url': 'https://api.github.com/users/codecov-io/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov-io/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-04T02:12:55Z',
#     'updated_at': '2019-12-04T02:12:55Z',
#     'author_association': 'NONE',
#     'body': '# [Codecov](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=h1) Report\n> :exclamation: No coverage uploaded for pull request base (`master@b0b9376`). [Click here to learn what that means](https://docs.codecov.io/docs/error-reference#section-missing-base-commit).\n> The diff coverage is `50%`.\n\n[![Impacted file tree graph](https://codecov.io/gh/apache/incubator-superset/pull/8746/graphs/tree.svg?width=650&token=KsB0fHcx6l&height=150&src=pr)](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=tree)\n\n```diff\n@@            Coverage Diff            @@\n##             master    #8746   +/-   ##\n=========================================\n  Coverage          ?   65.88%           \n=========================================\n  Files             ?      483           \n  Lines             ?    24121           \n  Branches          ?     2769           \n=========================================\n  Hits              ?    15892           \n  Misses            ?     8053           \n  Partials          ?      176\n```\n\n\n| [Impacted Files](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=tree) | Coverage Δ | |\n|---|---|---|\n| [superset/assets/src/explore/controls.jsx](https://codecov.io/gh/apache/incubator-superset/pull/8746/diff?src=pr&el=tree#diff-c3VwZXJzZXQvYXNzZXRzL3NyYy9leHBsb3JlL2NvbnRyb2xzLmpzeA==) | `41.6% <ø> (ø)` | |\n| [.../assets/src/visualizations/TimeTable/TimeTable.jsx](https://codecov.io/gh/apache/incubator-superset/pull/8746/diff?src=pr&el=tree#diff-c3VwZXJzZXQvYXNzZXRzL3NyYy92aXN1YWxpemF0aW9ucy9UaW1lVGFibGUvVGltZVRhYmxlLmpzeA==) | `0% <0%> (ø)` | |\n| [...re/components/controls/TimeSeriesColumnControl.jsx](https://codecov.io/gh/apache/incubator-superset/pull/8746/diff?src=pr&el=tree#diff-c3VwZXJzZXQvYXNzZXRzL3NyYy9leHBsb3JlL2NvbXBvbmVudHMvY29udHJvbHMvVGltZVNlcmllc0NvbHVtbkNvbnRyb2wuanN4) | `57.4% <100%> (ø)` | |\n\n------\n\n[Continue to review full report at Codecov](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=continue).\n> **Legend** - [Click here to learn more](https://docs.codecov.io/docs/codecov-delta)\n> `Δ = absolute <relative> (impact)`, `ø = not affected`, `? = missing data`\n> Powered by [Codecov](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=footer). Last update [b0b9376...b9b498b](https://codecov.io/gh/apache/incubator-superset/pull/8746?src=pr&el=lastupdated). Read the [comment docs](https://docs.codecov.io/docs/pull-request-comments).\n'}},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '11005542412',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46631702,
#    'name': 'Lombiq/Responsive-Pretty-Good-Base-Theme',
#    'url': 'https://api.github.com/repos/Lombiq/Responsive-Pretty-Good-Base-Theme'},
#   'payload': {'push_id': 4351996266,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev',
#    'head': 'c86f77f5f9a4bb9abc4c35e042efe67d598fa07b',
#    'before': 'c86f77f5f9a4bb9abc4c35e042efe67d598fa07b',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11005542407',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 43380114,
#    'name': 'Lombiq/Smart-Notifications',
#    'url': 'https://api.github.com/repos/Lombiq/Smart-Notifications'},
#   'payload': {'push_id': 4351996265,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.1',
#    'head': '447cdaf0f6fc401f45dd77110b1ee8e6b2ba7555',
#    'before': '447cdaf0f6fc401f45dd77110b1ee8e6b2ba7555',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11005542404',
#   'type': 'CreateEvent',
#   'actor': {'id': 44385231,
#    'login': 'ET-LINK',
#    'display_login': 'ET-LINK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ET-LINK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44385231?'},
#   'repo': {'id': 202513484,
#    'name': 'Entertech/Enter-AffectiveCloud-iOS-SDK',
#    'url': 'https://api.github.com/repos/Entertech/Enter-AffectiveCloud-iOS-SDK'},
#   'payload': {'ref': '1.3.7',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': '回车情感云 iOS SDK 和 演示 demo，通过此 SDK 实现快速接入情感云。',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 12285365,
#    'login': 'Entertech',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Entertech',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12285365?'}},
#  {'id': '11005542402',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 16627268,
#    'login': 'jenweber',
#    'display_login': 'jenweber',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jenweber',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16627268?'},
#   'repo': {'id': 191076497,
#    'name': 'ember-learn/ember-octane-vs-classic-cheat-sheet',
#    'url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/19',
#     'repository_url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet',
#     'labels_url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/19/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/19/comments',
#     'events_url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/19/events',
#     'html_url': 'https://github.com/ember-learn/ember-octane-vs-classic-cheat-sheet/pull/19',
#     'id': 532400927,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjU4MDM1',
#     'number': 19,
#     'title': 'Updates to the cheat sheet for the Octane launch',
#     'user': {'login': 'jenweber',
#      'id': 16627268,
#      'node_id': 'MDQ6VXNlcjE2NjI3MjY4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/16627268?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jenweber',
#      'html_url': 'https://github.com/jenweber',
#      'followers_url': 'https://api.github.com/users/jenweber/followers',
#      'following_url': 'https://api.github.com/users/jenweber/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jenweber/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jenweber/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jenweber/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jenweber/orgs',
#      'repos_url': 'https://api.github.com/users/jenweber/repos',
#      'events_url': 'https://api.github.com/users/jenweber/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jenweber/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-04T02:11:14Z',
#     'updated_at': '2019-12-04T02:12:55Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'pull_request': {'url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/pulls/19',
#      'html_url': 'https://github.com/ember-learn/ember-octane-vs-classic-cheat-sheet/pull/19',
#      'diff_url': 'https://github.com/ember-learn/ember-octane-vs-classic-cheat-sheet/pull/19.diff',
#      'patch_url': 'https://github.com/ember-learn/ember-octane-vs-classic-cheat-sheet/pull/19.patch'},
#     'body': 'Closes #18 \r\n\r\nChanged:\r\n- replaced Avatar references 😭 \r\n- Moved "default properties" into the Component Properties section\r\n- Replaced "Automation" links that went to codemods with links to the upgrade guide instead.\r\n\r\nAdded\r\n- Section on mixins\r\n- Section on generating element ids\r\n- Link to the upgrade guides in the intro text\r\n- Section on `@model`\r\n- Section on component generators\r\n- section on template co-location'},
#    'comment': {'url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/comments/561443670',
#     'html_url': 'https://github.com/ember-learn/ember-octane-vs-classic-cheat-sheet/pull/19#issuecomment-561443670',
#     'issue_url': 'https://api.github.com/repos/ember-learn/ember-octane-vs-classic-cheat-sheet/issues/19',
#     'id': 561443670,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MTQ0MzY3MA==',
#     'user': {'login': 'jenweber',
#      'id': 16627268,
#      'node_id': 'MDQ6VXNlcjE2NjI3MjY4',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/16627268?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jenweber',
#      'html_url': 'https://github.com/jenweber',
#      'followers_url': 'https://api.github.com/users/jenweber/followers',
#      'following_url': 'https://api.github.com/users/jenweber/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jenweber/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jenweber/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jenweber/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jenweber/orgs',
#      'repos_url': 'https://api.github.com/users/jenweber/repos',
#      'events_url': 'https://api.github.com/users/jenweber/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jenweber/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-04T02:12:55Z',
#     'updated_at': '2019-12-04T02:12:55Z',
#     'author_association': 'COLLABORATOR',
#     'body': '![Screenshot_2019-12-03 Ember js Classic vs Octane a cheat sheet](https://user-images.githubusercontent.com/16627268/70106444-a82d0800-1611-11ea-9dad-f77990e64bcc.png)\r\n'}},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 18540472,
#    'login': 'ember-learn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ember-learn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18540472?'}},
#  {'id': '11005542393',
#   'type': 'WatchEvent',
#   'actor': {'id': 57693403,
#    'login': 'creator-cheng',
#    'display_login': 'creator-cheng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/creator-cheng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57693403?'},
#   'repo': {'id': 54376220,
#    'name': 'AtsushiSakai/PythonRobotics',
#    'url': 'https://api.github.com/repos/AtsushiSakai/PythonRobotics'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542388',
#   'type': 'WatchEvent',
#   'actor': {'id': 6894266,
#    'login': 'genius-ua',
#    'display_login': 'genius-ua',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/genius-ua',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6894266?'},
#   'repo': {'id': 89225374,
#    'name': 'naver/egjs-infinitegrid',
#    'url': 'https://api.github.com/repos/naver/egjs-infinitegrid'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 6589568,
#    'login': 'naver',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/naver',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6589568?'}},
#  {'id': '11005542383',
#   'type': 'WatchEvent',
#   'actor': {'id': 47236374,
#    'login': 'calixo888',
#    'display_login': 'calixo888',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/calixo888',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47236374?'},
#   'repo': {'id': 62899021,
#    'name': 'openwisp/django-x509',
#    'url': 'https://api.github.com/repos/openwisp/django-x509'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 1150243,
#    'login': 'openwisp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openwisp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1150243?'}},
#  {'id': '11005542348',
#   'type': 'PushEvent',
#   'actor': {'id': 54591369,
#    'login': 'jyotisharmagwu',
#    'display_login': 'jyotisharmagwu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jyotisharmagwu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54591369?'},
#   'repo': {'id': 218057286,
#    'name': 'Jessa-Henderson/Final-Project-Group5',
#    'url': 'https://api.github.com/repos/Jessa-Henderson/Final-Project-Group5'},
#   'payload': {'push_id': 4351996233,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'af714fe9c67e5df5b2235929ebcd6f6a124064d3',
#    'before': '32fd6ed8ec495b9174a607738cec401b34ea3498',
#    'commits': [{'sha': 'af714fe9c67e5df5b2235929ebcd6f6a124064d3',
#      'author': {'email': '54591369+jyotisharmagwu@users.noreply.github.com',
#       'name': 'Jyoti sharma'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Jessa-Henderson/Final-Project-Group5/commits/af714fe9c67e5df5b2235929ebcd6f6a124064d3'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542382',
#   'type': 'CreateEvent',
#   'actor': {'id': 53452777,
#    'login': 'chmreid',
#    'display_login': 'chmreid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chmreid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53452777?'},
#   'repo': {'id': 84872231,
#    'name': 'HumanCellAtlas/data-store',
#    'url': 'https://api.github.com/repos/HumanCellAtlas/data-store'},
#   'payload': {'ref': 'chmreid-migrate-check-deployment-secrets-tests',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Design specs and prototypes for the HCA Data Storage System (DSS, "blue box")',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 26391798,
#    'login': 'HumanCellAtlas',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/HumanCellAtlas',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26391798?'}},
#  {'id': '11005542380',
#   'type': 'PushEvent',
#   'actor': {'id': 36459328,
#    'login': 'MickaelNguyen',
#    'display_login': 'MickaelNguyen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MickaelNguyen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36459328?'},
#   'repo': {'id': 210734457,
#    'name': 'MickaelNguyen/projectSoftwareEngineering',
#    'url': 'https://api.github.com/repos/MickaelNguyen/projectSoftwareEngineering'},
#   'payload': {'push_id': 4351996254,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '559e01b8c8b117b96d1fb77bb4b02323a3be74dc',
#    'before': 'f82ae71bdc57dad215d217794c509150f8b0e4f3',
#    'commits': [{'sha': '559e01b8c8b117b96d1fb77bb4b02323a3be74dc',
#      'author': {'email': '36459328+MickaelNguyen@users.noreply.github.com',
#       'name': 'MickaelNguyen'},
#      'message': 'Add files via upload\n\nCycle muscle session (rotation)+ Feedback impacting weights + Training Goals + Interactive map + Login + Create Account + Settings + User count',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MickaelNguyen/projectSoftwareEngineering/commits/559e01b8c8b117b96d1fb77bb4b02323a3be74dc'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542376',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 54688667,
#    'login': 'mete439',
#    'display_login': 'mete439',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mete439',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54688667?'},
#   'repo': {'id': 224305415,
#    'name': 'mete439/bus-mall',
#    'url': 'https://api.github.com/repos/mete439/bus-mall'},
#   'payload': {'action': 'closed',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/mete439/bus-mall/pulls/3',
#     'id': 348658308,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4NjU4MzA4',
#     'html_url': 'https://github.com/mete439/bus-mall/pull/3',
#     'diff_url': 'https://github.com/mete439/bus-mall/pull/3.diff',
#     'patch_url': 'https://github.com/mete439/bus-mall/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/mete439/bus-mall/issues/3',
#     'number': 3,
#     'state': 'closed',
#     'locked': False,
#     'title': ' about finishing lab11',
#     'user': {'login': 'mete439',
#      'id': 54688667,
#      'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mete439',
#      'html_url': 'https://github.com/mete439',
#      'followers_url': 'https://api.github.com/users/mete439/followers',
#      'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mete439/orgs',
#      'repos_url': 'https://api.github.com/users/mete439/repos',
#      'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mete439/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-04T02:12:33Z',
#     'updated_at': '2019-12-04T02:12:54Z',
#     'closed_at': '2019-12-04T02:12:54Z',
#     'merged_at': '2019-12-04T02:12:54Z',
#     'merge_commit_sha': 'de9e22101635fc01f8fe0436de905b194483e44e',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/mete439/bus-mall/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/mete439/bus-mall/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/mete439/bus-mall/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mete439/bus-mall/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/mete439/bus-mall/statuses/4746345c2b73b76daf83d3e2611acd7fa4b73c78',
#     'head': {'label': 'mete439:lab11_part1',
#      'ref': 'lab11_part1',
#      'sha': '4746345c2b73b76daf83d3e2611acd7fa4b73c78',
#      'user': {'login': 'mete439',
#       'id': 54688667,
#       'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mete439',
#       'html_url': 'https://github.com/mete439',
#       'followers_url': 'https://api.github.com/users/mete439/followers',
#       'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mete439/orgs',
#       'repos_url': 'https://api.github.com/users/mete439/repos',
#       'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mete439/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224305415,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQzMDU0MTU=',
#       'name': 'bus-mall',
#       'full_name': 'mete439/bus-mall',
#       'private': False,
#       'owner': {'login': 'mete439',
#        'id': 54688667,
#        'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mete439',
#        'html_url': 'https://github.com/mete439',
#        'followers_url': 'https://api.github.com/users/mete439/followers',
#        'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mete439/orgs',
#        'repos_url': 'https://api.github.com/users/mete439/repos',
#        'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mete439/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mete439/bus-mall',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/mete439/bus-mall',
#       'forks_url': 'https://api.github.com/repos/mete439/bus-mall/forks',
#       'keys_url': 'https://api.github.com/repos/mete439/bus-mall/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mete439/bus-mall/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mete439/bus-mall/teams',
#       'hooks_url': 'https://api.github.com/repos/mete439/bus-mall/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mete439/bus-mall/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mete439/bus-mall/events',
#       'assignees_url': 'https://api.github.com/repos/mete439/bus-mall/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mete439/bus-mall/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mete439/bus-mall/tags',
#       'blobs_url': 'https://api.github.com/repos/mete439/bus-mall/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mete439/bus-mall/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mete439/bus-mall/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mete439/bus-mall/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mete439/bus-mall/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mete439/bus-mall/languages',
#       'stargazers_url': 'https://api.github.com/repos/mete439/bus-mall/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mete439/bus-mall/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mete439/bus-mall/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mete439/bus-mall/subscription',
#       'commits_url': 'https://api.github.com/repos/mete439/bus-mall/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mete439/bus-mall/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mete439/bus-mall/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mete439/bus-mall/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mete439/bus-mall/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mete439/bus-mall/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mete439/bus-mall/merges',
#       'archive_url': 'https://api.github.com/repos/mete439/bus-mall/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mete439/bus-mall/downloads',
#       'issues_url': 'https://api.github.com/repos/mete439/bus-mall/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mete439/bus-mall/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mete439/bus-mall/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mete439/bus-mall/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mete439/bus-mall/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mete439/bus-mall/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mete439/bus-mall/deployments',
#       'created_at': '2019-11-26T23:36:06Z',
#       'updated_at': '2019-11-28T05:24:07Z',
#       'pushed_at': '2019-12-04T02:12:54Z',
#       'git_url': 'git://github.com/mete439/bus-mall.git',
#       'ssh_url': 'git@github.com:mete439/bus-mall.git',
#       'clone_url': 'https://github.com/mete439/bus-mall.git',
#       'svn_url': 'https://github.com/mete439/bus-mall',
#       'homepage': None,
#       'size': 1451,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'mete439:master',
#      'ref': 'master',
#      'sha': '768809d670b62140a06810c43d3c90f468861353',
#      'user': {'login': 'mete439',
#       'id': 54688667,
#       'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mete439',
#       'html_url': 'https://github.com/mete439',
#       'followers_url': 'https://api.github.com/users/mete439/followers',
#       'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mete439/orgs',
#       'repos_url': 'https://api.github.com/users/mete439/repos',
#       'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mete439/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 224305415,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQzMDU0MTU=',
#       'name': 'bus-mall',
#       'full_name': 'mete439/bus-mall',
#       'private': False,
#       'owner': {'login': 'mete439',
#        'id': 54688667,
#        'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mete439',
#        'html_url': 'https://github.com/mete439',
#        'followers_url': 'https://api.github.com/users/mete439/followers',
#        'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mete439/orgs',
#        'repos_url': 'https://api.github.com/users/mete439/repos',
#        'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mete439/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mete439/bus-mall',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/mete439/bus-mall',
#       'forks_url': 'https://api.github.com/repos/mete439/bus-mall/forks',
#       'keys_url': 'https://api.github.com/repos/mete439/bus-mall/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mete439/bus-mall/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mete439/bus-mall/teams',
#       'hooks_url': 'https://api.github.com/repos/mete439/bus-mall/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mete439/bus-mall/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mete439/bus-mall/events',
#       'assignees_url': 'https://api.github.com/repos/mete439/bus-mall/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mete439/bus-mall/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mete439/bus-mall/tags',
#       'blobs_url': 'https://api.github.com/repos/mete439/bus-mall/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mete439/bus-mall/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mete439/bus-mall/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mete439/bus-mall/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mete439/bus-mall/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mete439/bus-mall/languages',
#       'stargazers_url': 'https://api.github.com/repos/mete439/bus-mall/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mete439/bus-mall/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mete439/bus-mall/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mete439/bus-mall/subscription',
#       'commits_url': 'https://api.github.com/repos/mete439/bus-mall/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mete439/bus-mall/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mete439/bus-mall/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mete439/bus-mall/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mete439/bus-mall/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mete439/bus-mall/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mete439/bus-mall/merges',
#       'archive_url': 'https://api.github.com/repos/mete439/bus-mall/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mete439/bus-mall/downloads',
#       'issues_url': 'https://api.github.com/repos/mete439/bus-mall/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mete439/bus-mall/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mete439/bus-mall/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mete439/bus-mall/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mete439/bus-mall/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mete439/bus-mall/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mete439/bus-mall/deployments',
#       'created_at': '2019-11-26T23:36:06Z',
#       'updated_at': '2019-11-28T05:24:07Z',
#       'pushed_at': '2019-12-04T02:12:54Z',
#       'git_url': 'git://github.com/mete439/bus-mall.git',
#       'ssh_url': 'git@github.com:mete439/bus-mall.git',
#       'clone_url': 'https://github.com/mete439/bus-mall.git',
#       'svn_url': 'https://github.com/mete439/bus-mall',
#       'homepage': None,
#       'size': 1451,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mete439/bus-mall/pulls/3'},
#      'html': {'href': 'https://github.com/mete439/bus-mall/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/mete439/bus-mall/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/mete439/bus-mall/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mete439/bus-mall/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mete439/bus-mall/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mete439/bus-mall/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mete439/bus-mall/statuses/4746345c2b73b76daf83d3e2611acd7fa4b73c78'}},
#     'author_association': 'OWNER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'mete439',
#      'id': 54688667,
#      'node_id': 'MDQ6VXNlcjU0Njg4NjY3',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/54688667?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mete439',
#      'html_url': 'https://github.com/mete439',
#      'followers_url': 'https://api.github.com/users/mete439/followers',
#      'following_url': 'https://api.github.com/users/mete439/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mete439/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mete439/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mete439/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mete439/orgs',
#      'repos_url': 'https://api.github.com/users/mete439/repos',
#      'events_url': 'https://api.github.com/users/mete439/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mete439/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 85,
#     'deletions': 15,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542375',
#   'type': 'CreateEvent',
#   'actor': {'id': 56704343,
#    'login': 'glee139',
#    'display_login': 'glee139',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/glee139',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56704343?'},
#   'repo': {'id': 203943633,
#    'name': 'robosub-ucr/LeviathanAUV',
#    'url': 'https://api.github.com/repos/robosub-ucr/LeviathanAUV'},
#   'payload': {'ref': 'grace/camera-UI',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Software of the unnamedAUV for the 2020 RoboSub competition.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z',
#   'org': {'id': 54430356,
#    'login': 'robosub-ucr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/robosub-ucr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54430356?'}},
#  {'id': '11005542371',
#   'type': 'DeleteEvent',
#   'actor': {'id': 23040076,
#    'login': 'greenkeeper[bot]',
#    'display_login': 'greenkeeper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/greenkeeper[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23040076?'},
#   'repo': {'id': 186737474,
#    'name': 'hansololai/graphql_form',
#    'url': 'https://api.github.com/repos/hansololai/graphql_form'},
#   'payload': {'ref': 'greenkeeper/monorepo.storybook-20191202064256',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542365',
#   'type': 'PushEvent',
#   'actor': {'id': 57885986,
#    'login': 'adityabaguskuswadi',
#    'display_login': 'adityabaguskuswadi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adityabaguskuswadi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57885986?'},
#   'repo': {'id': 225758280,
#    'name': 'adityabaguskuswadi/Fromzero',
#    'url': 'https://api.github.com/repos/adityabaguskuswadi/Fromzero'},
#   'payload': {'push_id': 4351996237,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f8fbf1628bbb77b6ecc13956e36e302fca08274c',
#    'before': 'adc7aa9f0d1a63869e3db337c41358d8a3e80a11',
#    'commits': [{'sha': 'f8fbf1628bbb77b6ecc13956e36e302fca08274c',
#      'author': {'email': '57885986+adityabaguskuswadi@users.noreply.github.com',
#       'name': 'adityabaguskuswadi'},
#      'message': 'Add files via upload\n\nMateri HTML dan CSS',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adityabaguskuswadi/Fromzero/commits/f8fbf1628bbb77b6ecc13956e36e302fca08274c'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:55Z'},
#  {'id': '11005542369',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 55062079,
#    'login': 'KeeganMakesStuff',
#    'display_login': 'KeeganMakesStuff',
#    'gravatar_id': '',
# ...
#       'issues_url': 'https://api.github.com/repos/omiend/my_strongest_ror/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/omiend/my_strongest_ror/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/omiend/my_strongest_ror/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/omiend/my_strongest_ror/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/omiend/my_strongest_ror/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/omiend/my_strongest_ror/deployments',
#       'created_at': '2017-08-22T08:19:11Z',
#       'updated_at': '2019-12-04T02:12:13Z',
#       'pushed_at': '2019-12-04T02:12:54Z',
#       'git_url': 'git://github.com/omiend/my_strongest_ror.git',
#       'ssh_url': 'git@github.com:omiend/my_strongest_ror.git',
#       'clone_url': 'https://github.com/omiend/my_strongest_ror.git',
#       'svn_url': 'https://github.com/omiend/my_strongest_ror',
#       'homepage': None,
#       'size': 81,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'omiend:master',
#      'ref': 'master',
#      'sha': 'e012606209fe27815ae39bcc178c7e32de3baad4',
#      'user': {'login': 'omiend',
#       'id': 4135267,
#       'node_id': 'MDQ6VXNlcjQxMzUyNjc=',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/4135267?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/omiend',
#       'html_url': 'https://github.com/omiend',
#       'followers_url': 'https://api.github.com/users/omiend/followers',
#       'following_url': 'https://api.github.com/users/omiend/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/omiend/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/omiend/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/omiend/subscriptions',
#       'organizations_url': 'https://api.github.com/users/omiend/orgs',
#       'repos_url': 'https://api.github.com/users/omiend/repos',
#       'events_url': 'https://api.github.com/users/omiend/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/omiend/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 101039310,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMDEwMzkzMTA=',
#       'name': 'my_strongest_ror',
#       'full_name': 'omiend/my_strongest_ror',
#       'private': False,
#       'owner': {'login': 'omiend',
#        'id': 4135267,
#        'node_id': 'MDQ6VXNlcjQxMzUyNjc=',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/4135267?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/omiend',
#        'html_url': 'https://github.com/omiend',
#        'followers_url': 'https://api.github.com/users/omiend/followers',
#        'following_url': 'https://api.github.com/users/omiend/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/omiend/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/omiend/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/omiend/subscriptions',
#        'organizations_url': 'https://api.github.com/users/omiend/orgs',
#        'repos_url': 'https://api.github.com/users/omiend/repos',
#        'events_url': 'https://api.github.com/users/omiend/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/omiend/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/omiend/my_strongest_ror',
#       'description': 'ぼくがかんがえたさいきょうのRuby on Rails開発環境',
#       'fork': False,
#       'url': 'https://api.github.com/repos/omiend/my_strongest_ror',
#       'forks_url': 'https://api.github.com/repos/omiend/my_strongest_ror/forks',
#       'keys_url': 'https://api.github.com/repos/omiend/my_strongest_ror/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/omiend/my_strongest_ror/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/omiend/my_strongest_ror/teams',
#       'hooks_url': 'https://api.github.com/repos/omiend/my_strongest_ror/hooks',
#       'issue_events_url': 'https://api.github.com/repos/omiend/my_strongest_ror/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/omiend/my_strongest_ror/events',
#       'assignees_url': 'https://api.github.com/repos/omiend/my_strongest_ror/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/omiend/my_strongest_ror/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/omiend/my_strongest_ror/tags',
#       'blobs_url': 'https://api.github.com/repos/omiend/my_strongest_ror/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/omiend/my_strongest_ror/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/omiend/my_strongest_ror/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/omiend/my_strongest_ror/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/omiend/my_strongest_ror/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/omiend/my_strongest_ror/languages',
#       'stargazers_url': 'https://api.github.com/repos/omiend/my_strongest_ror/stargazers',
#       'contributors_url': 'https://api.github.com/repos/omiend/my_strongest_ror/contributors',
#       'subscribers_url': 'https://api.github.com/repos/omiend/my_strongest_ror/subscribers',
#       'subscription_url': 'https://api.github.com/repos/omiend/my_strongest_ror/subscription',
#       'commits_url': 'https://api.github.com/repos/omiend/my_strongest_ror/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/omiend/my_strongest_ror/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/omiend/my_strongest_ror/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/omiend/my_strongest_ror/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/omiend/my_strongest_ror/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/omiend/my_strongest_ror/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/omiend/my_strongest_ror/merges',
#       'archive_url': 'https://api.github.com/repos/omiend/my_strongest_ror/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/omiend/my_strongest_ror/downloads',
#       'issues_url': 'https://api.github.com/repos/omiend/my_strongest_ror/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/omiend/my_strongest_ror/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/omiend/my_strongest_ror/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/omiend/my_strongest_ror/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/omiend/my_strongest_ror/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/omiend/my_strongest_ror/deployments',
#       'created_at': '2017-08-22T08:19:11Z',
#       'updated_at': '2019-12-04T02:12:13Z',
#       'pushed_at': '2019-12-04T02:12:54Z',
#       'git_url': 'git://github.com/omiend/my_strongest_ror.git',
#       'ssh_url': 'git@github.com:omiend/my_strongest_ror.git',
#       'clone_url': 'https://github.com/omiend/my_strongest_ror.git',
#       'svn_url': 'https://github.com/omiend/my_strongest_ror',
#       'homepage': None,
#       'size': 81,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Ruby',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4,
#       'license': None,
#       'forks': 0,
#       'open_issues': 4,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls/9'},
#      'html': {'href': 'https://github.com/omiend/my_strongest_ror/pull/9'},
#      'issue': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/issues/9'},
#      'comments': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/issues/9/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls/9/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/pulls/9/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/omiend/my_strongest_ror/statuses/470f8819884f6fabe209e623ea36f15675189424'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'omiend',
#      'id': 4135267,
#      'node_id': 'MDQ6VXNlcjQxMzUyNjc=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/4135267?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/omiend',
#      'html_url': 'https://github.com/omiend',
#      'followers_url': 'https://api.github.com/users/omiend/followers',
#      'following_url': 'https://api.github.com/users/omiend/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/omiend/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/omiend/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/omiend/subscriptions',
#      'organizations_url': 'https://api.github.com/users/omiend/orgs',
#      'repos_url': 'https://api.github.com/users/omiend/repos',
#      'events_url': 'https://api.github.com/users/omiend/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/omiend/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542351',
#   'type': 'WatchEvent',
#   'actor': {'id': 15211960,
#    'login': 'outofpower',
#    'display_login': 'outofpower',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/outofpower',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15211960?'},
#   'repo': {'id': 93552083,
#    'name': 'JakeBecker/elixir-ls',
#    'url': 'https://api.github.com/repos/JakeBecker/elixir-ls'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542345',
#   'type': 'PushEvent',
#   'actor': {'id': 53903263,
#    'login': 'sanazaidichi',
#    'display_login': 'sanazaidichi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sanazaidichi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53903263?'},
#   'repo': {'id': 225293897,
#    'name': 'sanazaidichi/nested-hash-iteration-code-along-onl01-seng-pt-110319',
#    'url': 'https://api.github.com/repos/sanazaidichi/nested-hash-iteration-code-along-onl01-seng-pt-110319'},
#   'payload': {'push_id': 4351996228,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '51e11b0ccb290a555e5669f9b05489a75b1e6aba',
#    'before': 'd2a14044f10643f94b11aadd5725cc4233cfd3a4',
#    'commits': [{'sha': '51e11b0ccb290a555e5669f9b05489a75b1e6aba',
#      'author': {'email': 'sana.rizvi.5@gmail.com', 'name': 'Sana Zaidi'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sanazaidichi/nested-hash-iteration-code-along-onl01-seng-pt-110319/commits/51e11b0ccb290a555e5669f9b05489a75b1e6aba'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542342',
#   'type': 'PushEvent',
#   'actor': {'id': 55107306,
#    'login': 'jmthomas6',
#    'display_login': 'jmthomas6',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jmthomas6',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55107306?'},
#   'repo': {'id': 220073824,
#    'name': 'jmthomas6/PlatformerGroup5',
#    'url': 'https://api.github.com/repos/jmthomas6/PlatformerGroup5'},
#   'payload': {'push_id': 4351996222,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b9b0c6b97e4b0be4ec288af0e71c08d9f38e15c6',
#    'before': '64aa7f94d80650781fb21b0aba0a673ab57378e0',
#    'commits': [{'sha': 'b9b0c6b97e4b0be4ec288af0e71c08d9f38e15c6',
#      'author': {'email': '55107306+jmthomas6@users.noreply.github.com',
#       'name': 'Jonah T'},
#      'message': 'Room spawn tweaks',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jmthomas6/PlatformerGroup5/commits/b9b0c6b97e4b0be4ec288af0e71c08d9f38e15c6'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542341',
#   'type': 'PushEvent',
#   'actor': {'id': 50758721,
#    'login': 'deryatanriverdi88',
#    'display_login': 'deryatanriverdi88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/deryatanriverdi88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50758721?'},
#   'repo': {'id': 223040282,
#    'name': 'deryatanriverdi88/NutriTrack-Frontend',
#    'url': 'https://api.github.com/repos/deryatanriverdi88/NutriTrack-Frontend'},
#   'payload': {'push_id': 4351996220,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8af5995367616ed651e1d0662e579b9cc04c1cfd',
#    'before': '72a22fcc738878d90076c0938985003f3f17ad59',
#    'commits': [{'sha': '56897ecf4d64109ee819200b9942c6bb948bda7a',
#      'author': {'email': 'deryatanriverdi_@hotmail.com',
#       'name': 'deryatanriverdi88'},
#      'message': 'Changed math from backend to frontend',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/deryatanriverdi88/NutriTrack-Frontend/commits/56897ecf4d64109ee819200b9942c6bb948bda7a'},
#     {'sha': '8af5995367616ed651e1d0662e579b9cc04c1cfd',
#      'author': {'email': '50758721+deryatanriverdi88@users.noreply.github.com',
#       'name': 'deryatanriverdi88'},
#      'message': 'Merge pull request #35 from deryatanriverdi88/deryatanriverdi\n\nChanged math from backend to frontend',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/deryatanriverdi88/NutriTrack-Frontend/commits/8af5995367616ed651e1d0662e579b9cc04c1cfd'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'},
#  {'id': '11005542335',
#   'type': 'PushEvent',
#   'actor': {'id': 13054742,
#    'login': 'revswim',
#    'display_login': 'revswim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/revswim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13054742?'},
#   'repo': {'id': 225741426,
#    'name': 'revswim/jahbulon',
#    'url': 'https://api.github.com/repos/revswim/jahbulon'},
#   'payload': {'push_id': 4351996226,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ce64623c07fea8553e0564089a1268a196bbf862',
#    'before': '3c6a643dee233e91917c6a4a420ecb11c1973c58',
#    'commits': [{'sha': 'ce64623c07fea8553e0564089a1268a196bbf862',
#      'author': {'email': 'swimquixotic@gmail.com', 'name': 'revswim'},
#      'message': 'Update from Forestry.io\nrevswim deleted content/posts/photography.md\nrevswim updated content/posts/city-on-the-lake.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/revswim/jahbulon/commits/ce64623c07fea8553e0564089a1268a196bbf862'}]},
#   'public': True,
#   'created_at': '2019-12-04T02:12:54Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008b80aac31001185ed0d","text":"Adult cats only meow to communicate with humans.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e009650aac31001185ed13","text":"In the 1960s, the CIA tried to turn a cat into a bonafide spy by implanting a microphone into her ear and a radio transmitter at the base of her skull. She somehow survived the surgery but got hit by a taxi on her first mission.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b2b0aac31001185ed1f","text":"A cat has five toes on his front paws, and four on the back, unless he\'s a polydactyl.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00be30aac31001185edfe","text":"Cats use their whiskers to detect if they can fit through a space.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"58e00b4d0aac31001185ed22","text":"Original kitty litter was made out of sand but it was replaced by more absorbent clay in 1948.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":4,"userUpvoted":null},{"_id":"5b199196ce456e001424256a","text":"Cats can distinguish different flavors in water.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b1b411d841d9700146158d9","text":"The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"5b4912c60508220014ccfe99","text":"Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":4,"userUpvoted":null},{"_id":"58e007db0aac31001185ecf7","text":"There are cats who have survived falls from over 32 stories (320 meters) onto concrete.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e008800aac31001185ed07","text":"Wikipedia has a recording of a cat meowing, because why not?","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e009790aac31001185ed14","text":"The technical term for \\"hairball\\" is \\"bezoar.\\"","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"58e00a120aac31001185ed17","text":"A cat\'s brain is 90% similar to a human\'s — more similar than to a dog\'s.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":3,"userUpvoted":null},{"_id":"591d9b2f227c1a0020d26823","text":"Every year, nearly four million cats are eaten in China as a delicacy.","type":"cat","user":{"_id":"587288f6e6f85e64ae1c7ef7","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"5974fb4dfedacb0020b5b4cc","text":"Cats can survive falls from up to 65 feet or more.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":3,"userUpvoted":null},{"_id":"59a60ba66acf530020f35873","te ...
