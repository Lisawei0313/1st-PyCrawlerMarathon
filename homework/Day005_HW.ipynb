# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests
import json
import pandas as pd

r_pop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
r_npop = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')

resp_pop = r_pop.text
resp_npop = r_npop.text

#data_pop = json.loads(resp_pop)
#data_npop = json.loads(resp_npop)
df_pop = pd.read_json(resp_pop)
df_npop = pd.read_json(resp_npop)


##################################

df_pop = pd.read_json(resp_pop)
df_npop = pd.read_json(resp_npop)

print('熱門文章有%s筆資料\n' % len(df_pop))
print('非熱門文章有%s筆資料\n' % len(df_npop))
# Out:
# 熱門文章有30筆資料
#
# 非熱門文章有30筆資料

# %%
import json 
data = json.loads(response)
data_n =json.loads(response_n)
    
print('熱門文章有%s筆資料\n' % len(data))
print('非熱門文章有%s筆資料\n' % len(data_n))
# Out:
# 熱門文章有30筆資料
#
# 非熱門文章有30筆資料

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
cols_name = ['標題', '貼文時間', '留言人數', '按讚人數']

# 熱門文章
df_pop_r = df_pop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_pop_r.columns = cols_name
print('熱門文章:\n')
df_pop_r
# Out:
# 熱門文章:
#                                   標題                      貼文時間  留言人數  按讚人數
# 0                     我發誓牠們的食物是一樣的……  2019-12-02T15:47:50.672Z    22  1617
# 1                               覺得認同  2019-12-02T16:16:39.331Z    21   867
# 2   #CP值爆棚🔥包準可以安心侍奉主子們的安心居家清潔劑～隆重登場！  2019-12-03T07:01:36.591Z     6   302
# 3                            比特BB的心酸  2019-12-03T03:00:15.230Z    34   181
# 4                          養了一隻便便製造機  2019-12-02T19:36:06.064Z    25   106
# 5                              同學你的貓  2019-12-02T17:33:55.812Z     5   100
# 6                              中台小貓咪  2019-12-02T15:28:25.729Z     1    62
# 7                              寵物溝通師  2019-12-03T06:15:01.532Z     5    29
# 8                              掌上明鼠🐹  2019-12-03T10:33:32.723Z     6    28
# 9                             表情很浮誇喔  2019-12-02T15:36:01.429Z     0    18
# 10                           有養蛇的朋友嗎  2019-12-03T10:26:07.132Z    12    17
# 11                        板橋狗狗走失協尋🙏🏻  2019-12-03T08:12:02.860Z     1    17
# 12                          我怎麼就沒資格了  2019-12-03T00:58:21.934Z     7    16
# 13                         臘臘日腸 狗生很忙  2019-12-03T09:35:22.592Z     2    15
# 14                          同學你的倉鼠😍😍  2019-12-03T05:57:24.855Z     1    15
# 15                             鼠鼠跑步機  2019-12-03T05:19:42.813Z     5    15
# 16                    有人家的貓貓也會有這種反應嗎  2019-12-03T21:02:41.770Z     4    13
# 17                              命案現場  2019-12-03T14:15:30.889Z     3    12
# 18                           最近想養布偶貓  2019-12-03T05:00:37.016Z    17    12
# 19                       阿泥成長史1M->4M  2019-12-03T09:05:53.332Z     1    11
# 20                    冬天到了。躺在床上滑手機 。  2019-12-03T23:53:16.051Z     1    10
# 21                寵物協尋~拜託桃園的朋友可以多多留意  2019-12-03T10:23:17.008Z     1    10
# 22                            來求個食物ㄉ  2019-12-03T17:02:13.202Z     0     9
# 23                            小呆鼠🐹🐹🐹  2019-12-03T04:23:39.130Z     2     9
# 24                          蜥門慶硬硬硬硬硬  2019-12-03T15:42:20.058Z     3     8
# 25                    #圖 沒想到你有這種癖好⋯⋯  2019-12-03T14:45:02.471Z     2     8
# 26                           貓長腫瘤 #問  2019-12-03T13:57:46.871Z     6     8
# 27                              鸚鵡飛走  2019-12-03T05:01:42.285Z     1     8
# 28              #圖 我家那隻又愛又恨的臭兔兔＆用品分享  2019-12-03T14:27:21.303Z     7     6
# 29                        請問有養鸚鵡的前輩們  2019-12-03T13:05:58.245Z     4     6

# %%
df_npop_r = df_npop[['title', 'createdAt', 'commentCount', 'likeCount']]
df_npop_r.columns = cols_name
print('非熱門文章:\n')
df_npop_r
# Out:
# 非熱門文章:
#                       標題                      貼文時間  留言人數  按讚人數
# 0                 公貓結紮費用  2019-12-04T02:41:27.267Z     3     0
# 1               急！貓咪急救募款  2019-12-04T02:38:45.154Z     2     0
# 2         幫擴散 看到阿嬤這樣真的不捨  2019-12-04T02:30:58.065Z     0     2
# 3              尋找異父異母的兄弟  2019-12-04T02:19:16.100Z     0     2
# 4              貓的手手有出現🌈💕  2019-12-04T01:44:05.031Z     0     2
# 5              那個...妳很癢嗎  2019-12-04T01:33:56.260Z     3     1
# 6            #台中 #馬爾濟斯走失  2019-12-04T01:15:16.950Z     0     1
# 7                     金魚  2019-12-04T00:58:46.222Z     1     0
# 8         冬天到了。躺在床上滑手機 。  2019-12-03T23:53:16.051Z     1    10
# 9         有人家的貓貓也會有這種反應嗎  2019-12-03T21:02:41.770Z     4    14
# 10         各位請問一下你們會怎麼做？  2019-12-03T17:19:58.061Z     1     1
# 11                來求個食物ㄉ  2019-12-03T17:02:13.202Z     0     9
# 12             #圖 屁孩柴犬波波  2019-12-03T16:17:02.075Z     0     2
# 13              請問幼兔和寵物店  2019-12-03T15:54:14.774Z     2     2
# 14          #圖多 我家的公主狐狸犬  2019-12-03T15:51:29.308Z     1     5
# 15              蜥門慶硬硬硬硬硬  2019-12-03T15:42:20.058Z     3     8
# 16                     暖  2019-12-03T15:41:28.129Z     0     3
# 17        #圖 沒想到你有這種癖好⋯⋯  2019-12-03T14:45:02.471Z     2     8
# 18  #圖 我家那隻又愛又恨的臭兔兔＆用品分享  2019-12-03T14:27:21.303Z     7     6
# 19                  命案現場  2019-12-03T14:15:30.889Z     3    13
# 20              在我家的黃土高原  2019-12-03T14:12:57.092Z     5     3
# 21             貓咪怎麼老這樣坐著  2019-12-03T14:09:30.316Z     0     3
# 22               貓長腫瘤 #問  2019-12-03T13:57:46.871Z     6     8
# 23              黃金鼠給摸不給抓  2019-12-03T13:55:17.297Z     2     0
# 24            #急 新手養鬥魚求救  2019-12-03T13:52:49.200Z     1     4
# 25              博美vs貴賓選擇  2019-12-03T13:49:08.407Z     8     2
# 26            請問有養鸚鵡的前輩們  2019-12-03T13:05:58.245Z     4     6
# 27               公母不能一起養  2019-12-03T13:05:51.235Z     5     3
# 28         請問中興狗狗斷層掃描價格？  2019-12-03T12:43:50.826Z     0     2
# 29        狗愛吃貓的飼料貓愛吃狗的飼料  2019-12-03T12:36:47.945Z     7     1

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」


print('熱門文章-平均留言人數:', df_pop_r['留言人數'].mean())
print('熱門文章-平均按讚人數:', df_pop_r['按讚人數'].mean())
print('非熱門文章-平均留言人數:', df_npop_r['留言人數'].mean())
print('非熱門文章-平均按讚人數:', df_npop_r['按讚人數'].mean())
# Out:
# 熱門文章-平均留言人數: 6.833333333333333
# 熱門文章-平均按讚人數: 117.83333333333333
# 非熱門文章-平均留言人數: 2.3666666666666667
# 非熱門文章-平均按讚人數: 4.033333333333333
